# %%
from PIL import Image

# %%
word_matrix = Image.open('word_matrix.png')

# %%
mask = Image.open('mask.png')

# %%
word_matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559>

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251>

# %%
word_matrix.size
# Out:
# (1015, 559)

# %%
mask.size
# Out:
# (505, 251)

# %%
word_matrix = word_matrix.resize((505,251))

# %%
word_matrix
# Out:
# <PIL.Image.Image image mode=RGBA size=505x251>

# %%
mask.putalpha(50)

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251>

# %%
word_matrix.putalpha(50)

# %%
word_matrix.paste(im=mask,box=(0,0),mask=mask)

# %%
word_matrix
# Out:
# <PIL.Image.Image image mode=RGBA size=505x251>
